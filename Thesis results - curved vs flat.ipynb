# %%
dark_cpool = ['#1F78B4', '#E31A1C', '#33A02C', '#FF7F00', '#6A3D9A', '#02818A', 'k']
import matplotlib as mpl
mpl.rc('font', size=12)
cpool = ["#1F78B4", "#E31A1C", "#A6CEE3", "#FB9A99", "#7BCCC4", "#B2DF8A", "#33A02C", "#02818A", "#FF7F00", "#FDBF6F", "#CAB2D6", "#6A3D9A", "#BFD3E6", "#8C96C6"]

# %%
import os

# %%
fig_folder = '../../Thesis/fig/compare/'
if not os.path.isdir(fig_folder):
    os.mkdir(fig_folder)

# %% [markdown]
# ## Curved ala data

# %%
curved_lastlc = dict([ ('1',  [4.5, 4.75, 10.5, 6.5, 13.75, 13.0, 12.5, 11.25, 4.25, 4.5, 9.25, 14.5, 5.25, 9.75, 9.25, 13.0, 8.0, 6.0, 7.5, 8.25, 5.5, 18.0, 19.5, 6.0, 9.0, 8.25, 14.0, 13.5, 2.0, 9.25, 11.5, 8.0, 5.0, 11.5, 6.25, 13.0, 17.75, 4.75, 22.25, 20.75, 16.25, 16.0, 7.0, 7.0, 9.0, 9.25, 14.0, 5.5, 14.75, 9.25, 6.0, 14.25, 4.0, 2.5, 5.5, 15.75, 11.25, 1.25, 21.25, 7.25, 3.0, 19.5, 20.75, 15.25, 12.75, 15.75, 18.0, 12.5, 14.75, 12.25, 12.5, 9.0, 4.5, 2.75, 6.75, 7.75, 8.25, 22.0, 13.0, 10.25, 13.25, 6.5, 14.0, 7.75, 3.75, 15.75, 7.25, 10.75, 16.75, 5.75, 9.0, 9.0, 4.5, 3.75, 5.25, 6.5, 16.25, 8.25, 18.75, 13.25, 5.5, 8.25, 5.25, 11.0, 17.5, 11.5, 10.5, 10.5, 14.0, 5.0, 9.5, 11.0, 7.75, 13.5, 17.0, 14.25, 18.0, 14.0, 13.0, 8.5, 19.5, 11.25, 12.25, 5.25, 10.0, 11.5, 13.75, 19.25, 19.25, 14.0, 20.25, 10.0, 4.25, 14.25, 18.0, 13.5, 14.25, 16.0, 14.75, 12.75, 13.75, 17.5, 14.25, 5.0, 9.75, 12.25, 12.5, 11.0, 15.25, 13.5, 8.5, 14.0, 17.75, 8.25, 7.25, 11.25, 12.25, 16.25, 20.5, 16.0, 22.0, 24.0, 5.25, 14.5, 3.5, 7.75, 6.75, 13.0, 6.25, 6.25, 2.75, 4.25, 6.0, 8.75, 3.25, 5.25, 3.0, 2.5, 4.5, 1.75, 0.75, 3.75, 2.25, 7.0, 8.0, 7.75, 2.25, 1.5, 7.75, 16.5, 12.5, 12.0, 5.25, 2.0, 5.75, 15.25, 16.5, 5.0, 17.75, 8.0, 3.0, 1.5, 11.5, 3.0, 6.5, 8.25, 20.0, 16.75, 14.75, 9.25, 14.5, 22.75, 13.75, 19.25, 22.25, 17.0, 16.75, 9.0, 22.5, 24.5, 21.75, 30.75, 30.75, 27.5, 31.25, 40.0, 25.25, 30.25, 27.25, 18.5, 4.0, 9.25, 11.5, 3.25, 4.75, 2.0, 13.25, 19.25, 7.25, 9.0, 4.75, 11.0, 3.75, 
102.0, 113.5, 83.0, 90.0, 104.75, 107.5, 106.25, 93.75, 102.0, 84.0, 76.75, 87.75, 94.0, 109.5, 103.75, 96.5, 97.75, 98.25, 102.0, 91.75, 72.25, 81.5, 74.0, 82.75, 84.0, 97.0, 96.75, 103.0, 77.25, 78.75, 73.0, 77.5, 84.0, 91.5, 75.5, 84.5, 76.75, 89.75, 92.25, 74.75, 74.75, 76.25, 27.25, 27.0, 28.5, 59.75, 37.5, 24.75, 39.5, 34.75, 29.25, 30.0, 33.25, 27.75, 42.0, 27.0, 32.0, 43.5, 70.25, 42.5, 40.5, 37.75, 41.75, 37.0, 44.75, 43.75, 55.0, 45.75, 46.25, 35.75, 38.5, 64.5, 50.25, 47.5, 45.5, 31.75, 47.25, 48.75, 49.5, 27.0, 29.5, 49.0, 53.25, 36.0, 29.75, 42.25, 29.25, 39.25, 27.5, 29.25, 30.5, 38.5, 35.0, 31.75, 24.0, 42.0, 32.5, 25.25, 29.0, 33.5, 28.25, 34.0, 30.5, 35.25, 28.0, 31.25, 24.5, 42.25, 25.75, 37.75, 51.0, 13.25, 14.75, 19.25, 14.0, 16.75, 23.5, 18.75, 14.5, 13.0, 13.5, 10.0, 8.0, 19.25, 20.25, 19.0, 21.75, 18.0, 11.25, 15.5, 17.5, 4.5, 12.25, 12.5, 12.0, 19.0, 4.75, 14.25, 15.5, 12.0, 7.0, 5.75, 10.25, 16.75, 13.25, 10.75, 12.0, 14.75, 20.0, 12.5, 24.75, 28.25, 20.25, 19.0, 30.75, 36.75, 13.75, 23.0, 22.25, 15.5, 6.5, 37.25, 38.75, 22.25, 28.25, 26.25, 31.5] ), ])

# %%
type_names = ['1', '2', '3+', 'Early', 'Mult']
curved_lengths = [len(curved_lastlc[x]) for x in type_names]
flat_lengths = [len(flat_lastlc[x]) for x in type_names]
curved_Nsig = sum(curved_lengths)
flat_Nsig = sum(flat_lengths)
curved_percent = [round(x*100.0/curved_Nsig,2) for x in curved_lengths]
flat_percent = [round(x*100.0/flat_Nsig,2) for x in flat_lengths]

# %%
print curved_lengths
print flat_lengths
print curved_percent
print flat_percent
# Out:
# [288, 36, 30, 28, 202]
# [380, 253, 105, 194, 1021]
# [49.32, 6.16, 5.14, 4.79, 34.59]
# [19.46, 12.95, 5.38, 9.93, 52.28]

# %%
barlocs = arange(1.5, 6.5, 1)

# %%
figsize(6,4)
bar(barlocs-0.4, flat_percent, width=0.4, color=cpool[0])
bar(barlocs, curved_percent, width=0.4, color=cpool[1])
xticks(barlocs, type_names)
legend(['Flat', 'Curved'], fontsize=12, loc='upper center')
yt = yticks()[0]
ylim(0,60)
yper = ['%g%%' % x for x in yt]
yticks(yt, yper);
tight_layout()
savefig('%sbarplot_type_percent.pdf' % fig_folder)

# %%
curved_123 = curved_lastlc['1'] + curved_lastlc['2'] + curved_lastlc['3+']
flat_123 = flat_lastlc['1'] + flat_lastlc['2'] + flat_lastlc['3+']
print len(curved_123)
print len(flat_123)
# Out:
# 354
# 738

# %%
figsize(4,4)
hist(curved_123, alpha=0.5, color=cpool[1], bins = arange(0,150,5), histtype='stepfilled', normed=True);
hist(flat_123, alpha=0.5, color=cpool[0], bins = arange(0,150,5), histtype='stepfilled', normed=True);
legend(['Curved (%d)' % len(curved_123), 'Flat (%d)' % len(flat_123)])
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
tight_layout()
savefig('%sflat_curved_123_lastlc_hist.pdf' % fig_folder)

# %%
flat_123e = flat_123 + flat_lastlc['Early']
curved_123e = curved_123 + curved_lastlc['Early']
print len(flat_123e)
print len(curved_123e)
# Out:
# 932
# 382

# %%
figsize(4,4)
hist(curved_123e, alpha=0.5, color=cpool[1], bins = arange(0,150,5), histtype='stepfilled', normed=True);
hist(flat_123e, alpha=0.5, color=cpool[0], bins = arange(0,150,5), histtype='stepfilled', normed=True);
legend(['Curved (%d)' % len(curved_123e), 'Flat (%d)' % len(flat_123e)])
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
tight_layout()
savefig('%sflat_curved_123e_lastlc_hist.pdf' % fig_folder)

# %%
flat_123em = flat_123e + flat_lastlc['Mult']
curved_123em = curved_123e + curved_lastlc['Mult']
print len(flat_123em)
print len(curved_123em)
# Out:
# 1953
# 584

# %%
figsize(4,4)
hist(curved_123em, alpha=0.5, color=cpool[1], bins = arange(0,150,5), histtype='stepfilled', normed=True);
hist(flat_123em, alpha=0.5, color=cpool[0], bins = arange(0,150,5), histtype='stepfilled', normed=True);
legend(['Curved (%d)' % len(curved_123em), 'Flat (%d)' % len(flat_123em)])
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
tight_layout()
savefig('%sflat_curved_123em_lastlc_hist.pdf' % fig_folder)

# %%
figsize(10, 3.5)
subplot(131)
hist(curved_123, alpha=0.5, color=cpool[1], bins = arange(0,150,5), histtype='stepfilled', normed=True);
hist(flat_123, alpha=0.5, color=cpool[0], bins = arange(0,150,5), histtype='stepfilled', normed=True);
legend(['Curved (%d)' % len(curved_123), 'Flat (%d)' % len(flat_123)], fontsize=12)
xlim(0,150)
ylim(0,0.06)
yt=yticks()[0]
text(10, 0.055, '(a)')
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')

subplot(132)
hist(curved_123e, alpha=0.5, color=cpool[1], bins = arange(0,150,5), histtype='stepfilled', normed=True);
hist(flat_123e, alpha=0.5, color=cpool[0], bins = arange(0,150,5), histtype='stepfilled', normed=True);
legend(['Curved (%d)' % len(curved_123e), 'Flat (%d)' % len(flat_123e)], fontsize=12)
xlim(0,150)
ylim(0,0.06)
yticks(yt, ['' for x in yt])
text(10, 0.055, '(b)')
xlabel('Last $L_c$ (nm)')

subplot(133)
hist(curved_123em, alpha=0.5, color=cpool[1], bins = arange(0,150,5), histtype='stepfilled', normed=True);
hist(flat_123em, alpha=0.5, color=cpool[0], bins = arange(0,150,5), histtype='stepfilled', normed=True);
legend(['Curved (%d)' % len(curved_123em), 'Flat (%d)' % len(flat_123em)], fontsize=12)
xlim(0,150)
ylim(0,0.06)
yticks([])
yticks(yt, ['' for x in yt])
text(10, 0.055, '(c)')
xlabel('Last $L_c$ (nm)')
tight_layout()
savefig('%slast_lc_threetypes.pdf' % fig_folder)

# %%
figsize(10,6)
subplot(231)
hist(curved_lastlc['1'], bins=arange(0,150,5), normed=True, alpha=0.5, color=cpool[1], histtype='stepfilled')
hist(flat_lastlc['1'], bins=arange(0,150,5), normed=True, alpha=0.5, color=cpool[0], histtype='stepfilled')
y_max = axis()[3]
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
xlim(0,150)
text(130, y_max*0.85, '(a)')

subplot(232)
hist(curved_lastlc['2'], bins=arange(0,150,10), normed=True, alpha=0.5, color=cpool[1], histtype='stepfilled')
hist(flat_lastlc['2'], bins=arange(0,150,10), normed=True, alpha=0.5, color=cpool[0], histtype='stepfilled')
y_max = axis()[3]
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
text(130, y_max*0.85, '(b)')


subplot(233)
hist(curved_lastlc['3+'], bins=arange(0,160,20), normed=True, alpha=0.5, color=cpool[1], histtype='stepfilled')
hist(flat_lastlc['3+'], bins=arange(0,160,20), normed=True, alpha=0.5, color=cpool[0], histtype='stepfilled')
y_max = axis()[3]
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
text(130, y_max*0.85, '(c)')


subplot(234)
hist(curved_lastlc['Early'], bins=arange(0,160,20), normed=True, alpha=0.5, color=cpool[1], histtype='stepfilled')
hist(flat_lastlc['Early'], bins=arange(0,160,20), normed=True, alpha=0.5, color=cpool[0], histtype='stepfilled')
y_max = axis()[3]
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
text(130, y_max*0.85, '(d)')


subplot(235)
hist(curved_lastlc['Mult'], bins=arange(0,160,5), normed=True, alpha=0.5, color=cpool[1], histtype='stepfilled')
hist(flat_lastlc['Mult'], bins=arange(0,160,5), normed=True, alpha=0.5, color=cpool[0], histtype='stepfilled')
y_max = axis()[3]
xlim(0,150)
xlabel('Last $L_c$ (nm)')
ylabel('Frequency')
text(130, y_max*0.85, '(e)')

tight_layout()
savefig('%slast_lc_by_histtype.pdf' % fig_folder)

# %%
figsize(10,4)

subplot(121)
hist(flat_123, color=cpool[6], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(flat_lastlc['1']+flat_lastlc['2'], color=cpool[1], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(flat_lastlc['1'], color=cpool[0], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
xlim(0,120)
xlabel('Last $L_c$ (nm)')
ylabel('Count')
text(120*0.9, 120*0.9, '(a)')
ylim(0,120)

subplot(122)
hist(curved_123, color=cpool[6], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(curved_lastlc['1']+curved_lastlc['2'], color=cpool[1], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(curved_lastlc['1'], color=cpool[0], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
xlim(0,120)
ylim(0,90)
xlabel('Last $L_c$ (nm)')
ylabel('Count')
text(120*0.9, 90*0.9, '(b)')

tight_layout()
savefig('%soverlap_lastlc_123_hist.pdf' % fig_folder)

# %%
figsize(10,4)

subplot(121)
hist(flat_123em, color=cpool[4], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(flat_123e, color=cpool[8], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(flat_123, color=cpool[11], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
xlim(0,120)
xlabel('Last $L_c$ (nm)')
ylabel('Count')
text(120*0.9, 250*0.9, '(a)')

subplot(122)
hist(curved_123em, color=cpool[4], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(curved_123e, color=cpool[8], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
hist(curved_123, color=cpool[11], alpha=1, bins = arange(0,150, 5), normed=False, histtype='stepfilled', lw=0);
xlim(0,120)
xlabel('Last $L_c$ (nm)')
ylabel('Count')
text(120*0.9, 120*0.9, '(b)')

tight_layout()
savefig('%soverlap_lastlc_hist.pdf' % fig_folder)

# %%
figsize(10,6)

x_max = 120
bins0 = arange(0,150,5)
bins = arange(0,150,10)
bins2 = arange(0,160, 20)

xs = arange(0,140, 20)
xno = ['' for x in xs]

subplot(2,3,4)
hist(curved_lastlc['1'], color=cpool[0], bins = bins0);
xlim(0,x_max)
ylim(0,90)
xticks(xs)
ylabel('Count')
xlabel('Last $L_c$ (nm)')
text(x_max*0.85, 90*0.85, '(d)')

subplot(2,3,5)
hist(curved_lastlc['2'], color=cpool[1], bins = bins);
xlim(0,x_max)
ylim(0,90)
ylabel('Count')
xticks(xs)
xlabel('Last $L_c$ (nm)')
text(x_max*0.85, 90*0.85, '(e)')

subplot(2,3,6)
hist(curved_lastlc['3+'], color=cpool[6], bins = bins2);
xlim(0,x_max)
ylim(0,90)
ylabel('Count')
xticks(xs)
xlabel('Last $L_c$ (nm)')
text(x_max*0.85, 90*0.85, '(f)')

subplot(2,3,1)
hist(flat_lastlc['1'], color=cpool[0], bins = bins0);
xlim(0,x_max)
ylim(0,120)
ylabel('Count')
xticks(xs, xno)
text(x_max*0.85, 120*0.85, '(a)')

subplot(2,3,2)
hist(flat_lastlc['2'], color=cpool[1], bins = bins);
xlim(0,x_max)
ylim(0,120)
ylabel('Count')
xticks(xs, xno)
text(x_max*0.85, 120*0.85, '(b)')

subplot(2,3,3)
hist(flat_lastlc['3+'], color=cpool[6], bins = bins2);
xlim(0,x_max)
ylim(0,120)
ylabel('Count')
xticks(xs, xno)
text(x_max*0.85, 120*0.85, '(c)')

tight_layout()
savefig('%stype_compare_123.pdf' % fig_folder)

# %%
figsize(10,6)

x_max = 150
bins0 = arange(0,200,5)
bins = arange(0,200,10)
bins2 = arange(0,200, 20)

xs = arange(0,160, 20)
xno = ['' for x in xs]
cmax_y = 100
fmax_y = 140

subplot(2,3,4)
hist(curved_123, color=cpool[11], bins = bins0);
xlim(0,x_max)
ylim(0,cmax_y)
xticks(xs)
ylabel('Count')
xlabel('Last $L_c$ (nm)')
text(130, cmax_y*0.9, '(d)')


subplot(2,3,5)
hist(curved_lastlc['Early'], color=cpool[8], bins = bins2);
xlim(0,x_max)
ylim(0,cmax_y)
ylabel('Count')
xticks(xs)
xlabel('Last $L_c$ (nm)')
text(130, cmax_y*0.9, '(e)')

subplot(2,3,6)
hist(curved_lastlc['Mult'], color=cpool[4], bins = bins0);
xlim(0,x_max)
ylim(0,cmax_y)
ylabel('Count')
xticks(xs)
xlabel('Last $L_c$ (nm)')
text(130, cmax_y*0.9, '(f)')

subplot(2,3,1)
hist(flat_123, color=cpool[11], bins = bins0);
xlim(0,x_max)
ylim(0,fmax_y)
ylabel('Count')
xticks(xs, xno)
text(130, fmax_y*0.9, '(a)')


subplot(2,3,2)
hist(flat_lastlc['Early'], color=cpool[8], bins = bins2);
xlim(0,150)
ylim(0,fmax_y)
ylabel('Count')
xticks(xs, xno)
text(130, fmax_y*0.9, '(b)')


subplot(2,3,3)
hist(flat_lastlc['Mult'], color=cpool[4], bins = bins0);
xlim(0,x_max)
ylim(0, fmax_y)
ylabel('Count')
xticks(xs, xno)
text(130, fmax_y*0.9, '(c)')

tight_layout()
savefig('%stype_compare_123_early_mult.pdf' % fig_folder)

# %% [markdown]
# ## Statistics

# %%
print type_names
# Out:
# ['1', '2', '3+', 'Early', 'Mult']

# %%
print '\tFlat\t\t\tCurved'
print 'Type\tmean\tstd\t\tmean\tstd'
for t in type_names:
    c = curved_lastlc[t]
    f = flat_lastlc[t]
    print '%s\t%.1f\t%.1f\t\t%.1f\t%.1f' % (t, mean(f), std(f), mean(c), std(c))
# Out:
# 	Flat			Curved
# Type	mean	std		mean	std
# 1	12.0	7.3		11.9	7.0
# 2	26.7	11.9		45.4	70.0
# 3+	50.3	16.4		75.9	62.6
# Early	67.6	25.9		46.2	22.7
# Mult	37.0	21.9		32.8	21.3

# %%
print '\tFlat\t\t\tCurved'
print 'Type\tmedian\tstd\t\tmedian\tstd'
for t in type_names:
    c = curved_lastlc[t]
    f = flat_lastlc[t]
    print '%s\t%d\t%d\t\t%d\t%d' % (t, round(median(f)), round(std(f)), round(median(c)), round(std(c)))
# Out:
# 	Flat			Curved
# Type	median	std		median	std
# 1	11	7		11	7
# 2	25	12		17	70
# 3+	45	16		58	63
# Early	64	26		44	23
# Mult	31	22		26	21

# %%
print '\tFlat\t\t\t\tCurved'
print 'Type\tmean\tmedian\tstd\t\tmean\tmedian\tstd'
for t in type_names:
    c = asarray(curved_lastlc[t])
    f = asarray(flat_lastlc[t])
    c = c[c<180]
    f = f[f<180]
    print '%s\t%d\t%d\t%d\t\t%d\t%d\t%d' % (t, round(mean(f)), round(median(f)), round(std(f)), round(mean(c)), round(median(c)), round(std(c)))
# Out:
# 	Flat				Curved
# Type	mean	median	std		mean	median	std
# 1	12	11	7		12	11	7
# 2	27	25	12		21	15	12
# 3+	50	45	16		57	53	27
# Early	67	64	23		46	44	23
# Mult	37	31	22		33	26	21

# %%
print ' Flat &  &  &  & Curved\\\\'
print 'Type & mean & median & std & mean & median & std \\\\'
for t in type_names:
    c = asarray(curved_lastlc[t])
    f = asarray(flat_lastlc[t])
    c = c[c<180]
    f = f[f<180]
    print '%s & %d & %d & %d &  & %d & %d & %d \\\\' % (t, round(mean(f)), round(median(f)), round(std(f)), round(mean(c)), round(median(c)), round(std(c)))
# Out:
#  Flat &  &  &  & Curved\\
# Type & mean & median & std & mean & median & std \\
# 1 & 12 & 11 & 7 &  & 12 & 11 & 7 \\
# 2 & 27 & 25 & 12 &  & 21 & 15 & 12 \\
# 3+ & 50 & 45 & 16 &  & 57 & 53 & 27 \\
# Early & 67 & 64 & 23 &  & 46 & 44 & 23 \\
# Mult & 37 & 31 & 22 &  & 33 & 26 & 21 \\

# %%
print asarray(curved_lastlc['2'])[asarray(curved_lastlc['2']) < 180]
# Out:
# [ 16.25  16.75  14.5   24.5   15.    15.25  15.5   31.25  15.25  53.    12.5
#   18.    14.75  13.5    9.75  21.5   14.25  35.25  12.5   20.25  39.5
#   15.25  13.25  17.25   9.    11.    45.    14.75  38.75  28.5    9.    48.25]

# %%
print fig_folder
# Out:
# ../../Thesis/fig/compare/
